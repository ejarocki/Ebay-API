# %%
from dotenv import load_dotenv

# %%
pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in c:\users\12676\anaconda3\envs\learn-env\lib\site-packages (0.20.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import datetime
import ebaysdk
import sys
from ebaysdk.finding import Connection as finding
from ebaysdk.exception import ConnectionError

# %%
load_dotenv()
API_KEY=os.getenv('api_key')

# %%
class Ebay_21(object):
    def __init__(self, API_KEY):
        self.api_key = API_KEY
        self.st = st
        
    def fetch(self):
        try:
            api = finding(appid=self.api_key, domain='svcs.sandbox.ebay.com', 
                          debug=True, config_file=None)
            response = api.execute('findItemsAdvanced', {'keywords': 'phone'})
            for item in response.reply.searchResult.item:
                print(f'Title: {item.title}, Price: {item.sellingStatus.currentPrice.value}')
            #print(response.reply)
            #assert(response.reply.ack == 'Success')
            #assert(type(response.reply.timestamp) == datetime.datetime)
            #assert(type(response.reply.searchResult.item) == list)

            item = response.reply.searchResult.item[0]
            assert(type(item.listingInfo.endTime) == datetime.datetime)
            assert(type(response.dict()) == dict)

        except ConnectionError as e:
            print(e)
            print(e.response.dict())
    
    def parse(self):
        pass
#main driver
if __name__=='__main__':
    e = Ebay_21(API_KEY)
    e.fetch()
    e.parse()
# Out:
# 2022-04-08 13:21:29,260 ebaysdk [DEBUG]:execute: verb=findItemsAdvanced data={'keywords': 'phone'}
# 2022-04-08 13:21:29,261 ebaysdk [DEBUG]:REQUEST (09b99ab7-7139-4719-8b7c-7b8cff2361bd): POST https://svcs.sandbox.ebay.com/services/search/FindingService/v1
# 2022-04-08 13:21:29,261 ebaysdk [DEBUG]:headers={'X-EBAY-SOA-SERVICE-NAME': 'FindingService', 'X-EBAY-SOA-SERVICE-VERSION': '1.12.0', 'X-EBAY-SOA-SECURITY-APPNAME': 'ElijahJa-Finding-SBX-8dc4e6fed-6b4f5c9b', 'X-EBAY-SOA-GLOBAL-ID': 'EBAY-US', 'X-EBAY-SOA-OPERATION-NAME': 'findItemsAdvanced', 'X-EBAY-SOA-REQUEST-DATA-FORMAT': 'XML', 'X-EBAY-SOA-RESPONSE-DATA-FORMAT': 'XML', 'Content-Type': 'text/xml', 'User-Agent': 'eBaySDK/2.2.0 Python/3.8.5 Windows/10', 'X-EBAY-SDK-REQUEST-ID': '09b99ab7-7139-4719-8b7c-7b8cff2361bd', 'Content-Length': '176'}
# 2022-04-08 13:21:29,263 ebaysdk [DEBUG]:body=b'<?xml version=\'1.0\' encoding=\'utf-8\'?><findItemsAdvancedRequest xmlns="http://www.ebay.com/marketplace/search/v1/services"><keywords>phone</keywords></findItemsAdvancedRequest>'
# 2022-04-08 13:21:30,171 ebaysdk [DEBUG]:RESPONSE (09b99ab7-7139-4719-8b7c-7b8cff2361bd):
# 2022-04-08 13:21:30,173 ebaysdk [DEBUG]:elapsed time=0:00:00.816974
# 2022-04-08 13:21:30,176 ebaysdk [DEBUG]:status code=200
# 2022-04-08 13:21:30,178 ebaysdk [DEBUG]:headers={'rlogid': 't6buoajkbnmboh.%60hqilqq6brqfsjej%3F%3Ckuvgwjcoiglh%60jj%2Bcw%3Cmd.qctp5654-1800a31fe27-0x2339', 'x-ebay-soa-message-protocol': 'NONE', 'x-ebay-soa-response-data-format': 'XML', 'x-ebay-soa-global-id': 'EBAY-US', 'x-ebay-soa-locale-list': 'en-US_US', 'x-ebay-soa-service-name': '{http://www.ebay.com/marketplace/search/v1/services}FindingService', 'x-ebay-soa-request-id': '1800a31f-e270-abe3-54b3-cca7ffec2c99', 'x-ebay-soa-service-metrics': '448083160', 'x-ebay-soa-service-version': '1.13.0', 'x-ebay-soa-operation-name': 'findItemsAdvanced', 'content-type': 'text/xml;charset=UTF-8', 'date': 'Fri, 08 Apr 2022 17:21:30 GMT', 'server': 'ebay-proxy-server', 'x-envoy-upstream-service-time': '450', 'x-ebay-pop-id': 'UFES2-LVSAZ01-svcssandbox', 'transfer-encoding': 'chunked'}
# 2022-04-08 13:21:30,179 ebaysdk [DEBUG]:content=<?xml version='1.0' encoding='UTF-8'?><findItemsAdvancedResponse xmlns="http://www.ebay.com/marketplace/search/v1/services"><ack>Success</ack><version>1.13.0</version><timestamp>2022-04-08T17:21:30.600Z</timestamp><searchResult count="40"><item><itemId>110546940014</itemId><title>NOKIA 7.1 - Android 9.0 Pie - 64 GB - Dual Camera - Dual SIM Unlocked Smartphone</title><globalId>EBAY-US</globalId><primaryCategory><categoryId>9355</categoryId><categoryName>Cell Phones &amp; Smartphones</categoryName></primaryCategory><galleryURL>https://i.ebayimg.sandbox.ebay.com/images/g/mIEAAOSw8jZiRcwk/s-l140.jpg</galleryURL><viewItemURL>https://cgi.sandbox.ebay.com/NOKIA-7-1-Android-9-0-Pie-64-GB-Dual-Camera-Dual-SIM-Unlocked-Smartphone-/110546940014</viewItemURL><paymentMethod>PayPal</paymentMethod><autoPay>false</autoPay><postalCode>606**</postalCode><location>Chicago,IL,USA</location><country>US</country><shippingInfo><shippingServiceCost currencyId="USD">30.0</shippingServiceCost><shippingType>Flat</shippingType><shipToLocations>Worldwide</shipToLocations><expeditedShipping>true</expeditedShipping><oneDayShippingAvailable>false</oneDayShippingAvailable><handlingTime>1</handlingTime></shippingInfo><sellingStatus><currentPrice currencyId="USD">209.0</currentPrice><convertedCurrentPrice currencyId="USD">209.0</convertedCurrentPrice><sellingState>Active</sellingState><timeLeft>P21DT22H22M28S</timeLeft></sellingStatus><listingInfo><bestOfferEnabled>false</bestOfferEnabled><buyItNowAvailable>false</buyItNowAvailable><startTime>2022-03-31T15:43:58.000Z</startTime><endTime>2022-04-30T15:43:58.000Z</endTime><listingType>FixedPrice</listingType><gift>false</gift></listingInfo><returnsAccepted>true</returnsAccepted><condition><conditionId>1000</conditionId><conditionDisplayName>New</conditionDisplayName></condition><isMultiVariationListing>false</isMultiVariationListing><topRatedListing>false</topRatedListing></item><item><itemId>110546940207</itemId><title>Samsung Galaxy S10 , 128GB, Prism White - Unlocked (Renewed)</title><globalId>EBAY-US</globalId><primaryCategory><categoryId>9355</categoryId><categoryName>Cell Phones &amp; Smartphones</categoryName></primaryCategory><galleryURL>https://i.ebayimg.sandbox.ebay.com/images/g/j2MAAOSwgvliRdk5/s-l140.jpg</galleryURL><viewItemURL>https://cgi.sandbox.ebay.com/Samsung-Galaxy-S10-128GB-Prism-White-Unlocked-Renewed-/110546940207</viewItemURL><paymentMethod>PayPal</paymentMethod><autoPay>false</autoPay><postalCode>752**</postalCode><location>Dallas,TX,USA</location><country>US</country><shippingInfo><shippingServiceCost currencyId="USD">0.0</shippingServiceCost><shippingType>Free</shippingType><shipToLocations>Worldwide</shipToLocations><expeditedShipping>false</expeditedShipping><oneDayShippingAvailable>false</oneDayShippingAvailable><handlingTime>1</handlingTime></shippingInfo><sellingStatus><currentPrice currencyId="USD">298.0</currentPrice><convertedCurrentPrice currencyId="USD">298.0</convertedCurrentPrice><sellingState>Active</sellingState><timeLeft>P21DT23H17M56S</timeLeft></sellingStatus><listingInfo><bestOfferEnabled>false</bestOfferEnabled><buyItNowAvailable>false</buyItNowAvailable><startTime>2022-03-31T16:39:26.000Z</startTime><endTime>2022-04-30T16:39:26.000Z</endTime><listingType>FixedPrice</listingType><gift>false</gift></listingInfo><returnsAccepted>true</returnsAccepted><condition><conditionId>1000</conditionId><conditionDisplayName>New</conditionDisplayName></condition><isMultiVariationListing>false</isMultiVariationListing><topRatedListing>false</topRatedListing></item><item><itemId>110547085548</itemId><title>Auction SKU</title><globalId>EBAY-US</globalId><primaryCategory><categoryId>9355</categoryId><categoryName>Cell Phones &amp; Smartphones</categoryName></primaryCategory><galleryURL></galleryURL><viewItemURL>https://cgi.sandbox.ebay.com/Auction-SKU-/110547085548</viewItemURL><productId type="ReferenceID">117353347</productId><paymentMet ...
# 2022-04-08 13:21:30,206 ebaysdk [DEBUG]:total time=0.9449269771575928
# Title: NOKIA 7.1 - Android 9.0 Pie - 64 GB - Dual Camera - Dual SIM Unlocked Smartphone, Price: 209.0
# Title: Samsung Galaxy S10 , 128GB, Prism White - Unlocked (Renewed), Price: 298.0
# Title: Auction SKU, Price: 10.0
# Title: SAMSUNG Galaxy Note8 N950U 64GB Unlocked GSM LTE Android Phone w/ Dual 12, Price: 850.72
# Title: SAMSUNG Galaxy S9 G960U 64GB Unlocked GSM 4G LTE Phone w/ 12MP Camera - Midnight, Price: 499.99
# Title: Product 8, Price: 134.0
# Title: apple phone for new version 3g, Price: 15.99
# Title: apple phone for new version 3g, Price: 15.99
# Title: simple 1 test, Price: 83.88
# Title: Gray/Gold Samsung Galaxy S8 Active SM-G892A 64GB AT&T GSM Unlocked New Sealed, Price: 240.99
# Title: Samsung Galaxy A11 32 GB No Returns / NET Price Black Unlocked Devices, Price: 206.49
# Title: Blackview OSCAL C60 Unlocked Smartphones 6.5" 4G Android Dual SIM Mobile Phone, Price: 136.99
# Title: Ulefone Power Armor 13 256GB Smartphone Android 11 6.81" 4G Cell Phone 13200mAh, Price: 399.89
# Title: DOOGEE V20 5G Rugged Smartphone 8 256GB Unlocked 6000mAh 6.43"FHD AMOLED Display, Price: 478.99
# Title: iPhone 13 Pro, Price: 999.99
# Title: iPhone 7 256gb, Price: 999.99
# Title: DOOGEE V20 5G Rugged Smartphone 8GB 256GB 6.43"FHD AMOLED Display 64MP IP68 NFC, Price: 479.99
# Title: Test Config For Tests123, Price: 240.0
# Title: SONY Alpha a5100 24.3MP Digital Camera - Black (with E PZ OSS 16-50mm Lens), Price: 150.0
# Title: simple 1 test, Price: 7.38
# Title: NEW MOBILE, Price: 500.0
# Title: Brooklyn Jean Jacket-9 qty, Price: 24.0
# Title: MIUI Mobile, Price: 1000.0
# Title: TEST TEST TEST, Price: 63.56
# Title: CaseMe Wallet Leather Flip Stand Phone Skin Cases for Samsung Galaxy S10 Plus 5G, Price: 6.99
# Title: Phone Case For iPhone 13 PRO MAX 12 11 Floral Personalised Name Clear TPU Cover, Price: 6.98
# Title: Personalised Glitter Case For iPhone 13 Pro Max 12 Mini 11 8 7 XR SE Phone Cover, Price: 6.98
# Title: For iPhone 13 Pro 12 11 Pro Max XR 8 Plus Cartoon Bling Glitter Phone Case Cover, Price: 10.99
# Title: Cordking iPhone XR Cases, Silicone Ultra Slim Shockproof Phone Case with [Soft, Price: 11.98
# Title: Phone Case For Samsung Galaxy A03S A12 A32 A53 A13 Personalised Marble TPU Cover, Price: 6.98
# Title: Apple iPhone 5C 3G Mobile Phone 4.0 Display Dual Core Cell, Price: 15.99
# Title: Original Apple iPhone 6C 4G Mobile Phone 5.0 Display Core phone, Price: 15.99
# Title: Original Apple iPhone 5C 3G Mobile Phone 4.0 Display Dual Core Cell, Price: 19.0
# Title: Original Apple iPhone 6C 3G Mobile Phone 4.0 Display Dual Core Cell, Price: 19.0
# Title: Original Apple iPhone 5C 3G Mobile Phone 4.0 Display Dual Core CellPhone, Price: 15.99
# Title: Ulefone Power Armor 13 256GB Smartphone Android 11 6.81" 4G Cell Phone 13200mAh, Price: 399.89
# Title: iPhone 12  Pro, Price: 999.99
# Title: Apple iPhone 11 Pro, Price: 999.99
# Title: Lauren Polo shirt Pink Black, Price: 15.99
# Title: Personalised Glitter Case For iPhone 13 Pro Max 12 Mini 11 8 7 XR SE Phone Cover, Price: 6.98

# %%
import os
import datetime
import sys
from ebaysdk.exception import ConnectionError
from ebaysdk.finding import Connection

# API key is set in .env file - create and save in same directory
from dotenv import load_dotenv
load_dotenv()
API_KEY=os.getenv('api_key')

class Ebay_21(object):
    def __init__(self, API_KEY,st):
        self.api_key = API_KEY
        self.st = st
    
    
    def fetch(self):
        try:
            api = Connection(appid=self.api_key, config_file=None, siteid="EBAY-GB")
            response = api.execute('findItemsAdvanced', {'keywords': st})
            
            #The total number of items found that match the search criteria in your request
            print(f"Total items {response.reply.paginationOutput.totalEntries}\n")
            
            for item in response.reply.searchResult.item:
                print(f"Title: {item.title}, Price: {item.sellingStatus.currentPrice.value}")
                print(f"Buy it now available : {item.listingInfo.buyItNowAvailable}")
                print(f"Country : {item.country}")
                print(f"End time :{item.listingInfo.endTime}")
                print(f"URL : {item.viewItemURL}")
                try:
                    print(f"Watchers : {item.listingInfo.watchCount}\n")
                except:
                    pass
  
        except ConnectionError as e:
            print(e)
            print(e.response.dict())
    
    def parse(self):
        pass
    

# main driver
if __name__=='__main__':
    
    # check if keyword was passed when calling script
    if len(sys.argv) ==1:
        print("Needs at least 1 search keywowrd")
        sys.exit(1)
    
    # set search term as 'st' and create instance of Ebay_21 to make API call 
    st = sys.argv[1]
    e = Ebay_21(API_KEY, st)
    e.fetch()
    e.parse()
# Out:
# 2022-04-08 10:20:39,536 ebaysdk [DEBUG]:execute: verb=findItemsAdvanced data={'keywords': '-f'}
# 2022-04-08 10:20:39,537 ebaysdk [DEBUG]:REQUEST (06ad26a8-9314-4c63-ab03-863a8bd306c3): POST https://svcs.ebay.com/services/search/FindingService/v1
# 2022-04-08 10:20:39,539 ebaysdk [DEBUG]:headers={'X-EBAY-SOA-SERVICE-NAME': 'FindingService', 'X-EBAY-SOA-SERVICE-VERSION': '1.12.0', 'X-EBAY-SOA-SECURITY-APPNAME': 'ElijahJa-Finding-SBX-8dc4e6fed-6b4f5c9b', 'X-EBAY-SOA-GLOBAL-ID': 'EBAY-GB', 'X-EBAY-SOA-OPERATION-NAME': 'findItemsAdvanced', 'X-EBAY-SOA-REQUEST-DATA-FORMAT': 'XML', 'X-EBAY-SOA-RESPONSE-DATA-FORMAT': 'XML', 'Content-Type': 'text/xml', 'User-Agent': 'eBaySDK/2.2.0 Python/3.8.5 Windows/10', 'X-EBAY-SDK-REQUEST-ID': '06ad26a8-9314-4c63-ab03-863a8bd306c3', 'Content-Length': '173'}
# 2022-04-08 10:20:39,539 ebaysdk [DEBUG]:body=b'<?xml version=\'1.0\' encoding=\'utf-8\'?><findItemsAdvancedRequest xmlns="http://www.ebay.com/marketplace/search/v1/services"><keywords>-f</keywords></findItemsAdvancedRequest>'
# 2022-04-08 10:20:39,876 ebaysdk [DEBUG]:RESPONSE (06ad26a8-9314-4c63-ab03-863a8bd306c3):
# 2022-04-08 10:20:39,878 ebaysdk [DEBUG]:elapsed time=0:00:00.335678
# 2022-04-08 10:20:39,879 ebaysdk [DEBUG]:status code=500
# 2022-04-08 10:20:39,880 ebaysdk [DEBUG]:headers={'rlogid': 't6buoajkbnmboh9%3Fuk%60dvnelhcjkanl%28lsrbr*w%60ut3522-180098c7045-0x2328', 'x-ebay-client-tls-version': 'TLSv1.3', 'x-ebay-soa-message-protocol': 'NONE', 'x-ebay-soa-response-data-format': 'XML', 'x-ebay-soa-global-id': 'EBAY-GB', 'x-ebay-soa-locale-list': 'en-GB_GB', 'x-ebay-soa-service-name': '{http://www.ebay.com/marketplace/search/v1/services}FindingService', 'x-ebay-soa-request-id': '180098c7-0460-acb1-22d1-753fffb75f70!FindingService!10.203.18.45!r1apifindingio[]', 'x-ebay-soa-error-response': 'TRUE', 'x-ebay-soa-service-metrics': '3770726', 'x-ebay-soa-service-version': '1.13.0', 'x-ebay-soa-operation-name': 'findItemsAdvanced', 'content-type': 'text/xml;charset=UTF-8', 'date': 'Fri, 08 Apr 2022 14:20:40 GMT', 'server': 'ebay-proxy-server', 'x-envoy-upstream-service-time': '21', 'x-ebay-pop-id': 'UFES2-SLCAZ01-svcs', 'transfer-encoding': 'chunked'}
# 2022-04-08 10:20:39,881 ebaysdk [DEBUG]:content=<?xml version='1.0' encoding='UTF-8'?><errorMessage xmlns="http://www.ebay.com/marketplace/search/v1/services"><error><errorId>11002</errorId><domain>Security</domain><severity>Error</severity><category>System</category><message>Authentication failed : Invalid Application: ElijahJa-Finding-SBX-8dc4e6fed-6b4f5c9b</message><subdomain>Authentication</subdomain><parameter name="Param1">Invalid Application: ElijahJa-Finding-SBX-8dc4e6fed-6b4f5c9b</parameter></error></errorMessage>
# 2022-04-08 10:20:39,888 ebaysdk [ERROR]:findItemsAdvanced: Internal Server Error, Domain: Security, Severity: Error, errorId: 11002, Authentication failed : Invalid Application: ElijahJa-Finding-SBX-8dc4e6fed-6b4f5c9b
# 'findItemsAdvanced: Internal Server Error, Domain: Security, Severity: Error, errorId: 11002, Authentication failed : Invalid Application: ElijahJa-Finding-SBX-8dc4e6fed-6b4f5c9b'
# {'errorMessage': {'error': {'errorId': '11002', 'domain': 'Security', 'severity': 'Error', 'category': 'System', 'message': 'Authentication failed : Invalid Application: ElijahJa-Finding-SBX-8dc4e6fed-6b4f5c9b', 'subdomain': 'Authentication', 'parameter': {'_name': 'Param1', 'value': 'Invalid Application: ElijahJa-Finding-SBX-8dc4e6fed-6b4f5c9b'}}}}

# %%
print(fetch(Ebay_21))
# Out:
# None

# %%
pip install beautifulsoup4

# %%
item_name = []
prices = []

for i in range(1,10):

    ebayUrl = "https://www.ebay.com/sch/i.html?_from=R40&_trksid=p2334524.m570.l1313&_nkw=galaxy+note&_sacat=0&LH_TitleDesc=0&_odkw=new+galaxy+note&_osacat=0_pgn="+str(i)
    r= requests.get(ebayUrl)
    data=r.text
    soup=BeautifulSoup(data)

    listings = soup.find_all('li', attrs={'class': 's-item'})

    for listing in listings:
        prod_name=" "
        prod_price = " "
        for name in listing.find_all('h3', attrs={'class':"s-item__title"}):
            if(str(name.find(text=True, recursive=False))!="None"):
                prod_name=str(name.find(text=True, recursive=False))
                item_name.append(prod_name)

        if(prod_name!=" "):
            price = listing.find('span', attrs={'class':"s-item__price"})
            prod_price = str(price.find(text=True, recursive=False))
            prod_price = int(sub(",","",prod_price.split("INR")[1].split(".")[0]))
            prices.append(prod_price)

from scipy import stats
import numpy as np

data_note_8 = pd.DataFrame({"Name":item_name, "Prices": prices})
#data_note_8 = data_note_8.iloc[np.abs(stats.zscore(data_note_8["Prices"]))&amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;lt; 3,]

# %% [markdown]
# Tags for extraction

# %%
#Chrome webdriver to prepare for data scraping
url = 'https://www.vivino.com/explore?e=eJzLLbI1VMvNzLM1UMtNrACSyZW2ocFqyUDCRa0AKJeeZluWWJSZWpKYo5ZflGKrlp9UaatWbJuXBQAuDhMm'
s = Service('chromedriver')
driver = webdriver.Chrome(service=s)
driver.get(url)
time.sleep(3)

scroll_pause_time = 3

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(scroll_pause_time)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

name=[]
location=[]
rating=[]
num_rating=[]
price = []

soup = BeautifulSoup(driver.page_source, "html.parser")
for wine in soup.find_all('a', class_='_3qc2M wineCard__cardLink--3F_uB'):
    name.append(wine.find(class_="wineInfoVintage__vintage--VvWlU wineInfoVintage__truncate--3QAtw").text)
    location.append(wine.find(class_='wineInfoLocation__regionAndCountry--1nEJz').text)
    rating.append(wine.find(class_='_19ZcA').text)
    num_rating.append(wine.find(class_= '_1_k5A').text)
    #price.append(wine.find(class_='addToCart__subText--1pvFt addToCart__ppcPrice--ydrd5').text)
